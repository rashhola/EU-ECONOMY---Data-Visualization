# %%
import requests
import pandas as pd
import json 
from sqlalchemy.engine import create_engine
from sqlalchemy import types
import sqlalchemy
from sqlalchemy import create_engine
from sqlalchemy import inspect
from sqlalchemy.ext.automap import automap_base
from sqlalchemy.orm import Session

# %%
import psycopg2

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:5432/economy_db")

# %%
inspector = inspect(engine)

# %%
Base = automap_base()
Base.prepare(engine, reflect=True)
Base.classes.keys()
# Out:
# ['cpi', 'countries', 'unemployment', 'population', 'gdp', 'gdpp', 'inflations']

# %%
Countries = Base.classes.countries
Unemployment = Base.classes.unemployment
Population = Base.classes.population
Gdp = Base.classes.gdp
Cpi = Base.classes.cpi
Gdp2 = Base.classes.gdpp
Inflation = Base.classes.inflations
# Combination = Base.classes.combine

# %%
inspector.get_table_names()
# Out:
# ['cpi', 'unemployment', 'population', 'countries', 'gdp', 'gdpp', 'inflations']

# %%
session = Session(engine)

# %%
session.query(Countries.country_name,Countries.color).all()
# Out:
# [('Austria', '#a80f13'),
#  ('Belgium', '#FFFF66'),
#  ('Bulgaria', '#00966E'),
#  ('Cyprus', '#D57800'),
#  ('Czech Republic', '#11457E'),
#  ('Germany', '#FFCD00'),
#  ('Denmark', '#8dbcf4'),
#  ('Spain', '#e60000'),
#  ('Estonia', '#999999'),
#  ('Finland', '#33CCFF'),
#  ('France', '#789263'),
#  ('Greece', '#0000ff'),
#  ('Croatia', '#dbc6a9'),
#  ('Hungary', '#6c1245'),
#  ('Ireland', '#a8e549'),
#  ('Italy', '#006600'),
#  ('Lithuania', '#55107e'),
#  ('Luxembourg', '#3366FF'),
#  ('Latvia', '#aa6f73'),
#  ('Malta', '#009999'),
#  ('Netherlands', '#9999FF'),
#  ('Poland', '#ff8b94'),
#  ('Portugal', '#a8e6cf'),
#  ('Romania', '#ff7400'),
#  ('Slovak Republic', '#ff4d00'),
#  ('Slovenia', '#e6e6d1'),
#  ('Sweden', '#FF99CC')]

# %%
session.query(Unemployment.country_name,Unemployment.ump_year,Unemployment.unemployment_pct).all()
# Out:
# [('Austria', 2005, 5.63),
#  ('Belgium', 2005, 8.44),
#  ('Bulgaria', 2005, 10.08),
#  ('Croatia', 2005, 12.6),
#  ('Cyprus', 2005, 5.3),
#  ('Czech Republic', 2005, 7.93),
#  ('Denmark', 2005, 4.83),
#  ('Estonia', 2005, 8.03),
#  ('Finland', 2005, 8.38),
#  ('France', 2005, 8.49),
#  ('Germany', 2005, 11.17),
#  ('Greece', 2005, 9.99),
#  ('Hungary', 2005, 7.19),
#  ('Ireland', 2005, 4.34),
#  ('Italy', 2005, 7.73),
#  ('Latvia', 2005, 10.03),
#  ('Lithuania', 2005, 8.33),
#  ('Luxembourg', 2005, 4.49),
#  ('Malta', 2005, 6.92),
#  ('Netherlands', 2005, 5.87),
#  ('Poland', 2005, 17.75),
#  ('Portugal', 2005, 7.58),
#  ('Romania', 2005, 7.17),
#  ('Slovak Republic', 2005, 16.26),
#  ('Slovenia', 2005, 6.51),
#  ('Spain', 2005, 9.15),
#  ('Sweden', 2005, 7.49),
#  ('Austria', 2006, 5.24),
#  ('Belgium', 2006, 8.25),
#  ('Bulgaria', 2006, 8.95),
#  ('Croatia', 2006, 11.13),
#  ('Cyprus', 2006, 4.54),
#  ('Czech Republic', 2006, 7.15),
#  ('Denmark', 2006, 3.9),
# ...

# %%
session.query(Population.country_name,Population.pop_year,Population.population).all()
# Out:
# [('Austria', 2005, 8227829),
#  ('Austria', 2006, 8268641),
#  ('Austria', 2007, 8295487),
#  ('Austria', 2008, 8321496),
#  ('Austria', 2009, 8343323),
#  ('Austria', 2010, 8363404),
#  ('Austria', 2011, 8391643),
#  ('Austria', 2012, 8429991),
#  ('Austria', 2013, 8479823),
#  ('Austria', 2014, 8546356),
#  ('Austria', 2015, 8642699),
#  ('Austria', 2016, 8736668),
#  ('Austria', 2017, 8797566),
#  ('Austria', 2018, 8840521),
#  ('Austria', 2019, 8877067),
#  ('Belgium', 2005, 10478617),
#  ('Belgium', 2006, 10547958),
#  ('Belgium', 2007, 10625700),
#  ('Belgium', 2008, 10709973),
#  ('Belgium', 2009, 10796493),
#  ('Belgium', 2010, 10895586),
#  ('Belgium', 2011, 11038264),
#  ('Belgium', 2012, 11106932),
#  ('Belgium', 2013, 11159407),
#  ('Belgium', 2014, 11209057),
#  ('Belgium', 2015, 11274196),
#  ('Belgium', 2016, 11331422),
#  ('Belgium', 2017, 11375158),
#  ('Belgium', 2018, 11427054),
#  ('Belgium', 2019, 11484055),
#  ('Bulgaria', 2005, 7658972),
# ...

# %%
session.query(Gdp.country_name, Gdp.last_v, Gdp.gdp_usd).all()
# Out:
# [('Austria', Decimal('38403'), Decimal('38403')),
#  ('Austria', Decimal('40635'), Decimal('38403')),
#  ('Austria', Decimal('46856'), Decimal('40635')),
#  ('Austria', Decimal('51709'), Decimal('46856')),
#  ('Austria', Decimal('47963'), Decimal('51709')),
#  ('Austria', Decimal('46858'), Decimal('47963')),
#  ('Austria', Decimal('51375'), Decimal('46858')),
#  ('Austria', Decimal('48568'), Decimal('51375')),
#  ('Austria', Decimal('50717'), Decimal('48568')),
#  ('Austria', Decimal('51717'), Decimal('50717')),
#  ('Austria', Decimal('44178'), Decimal('51717')),
#  ('Austria', Decimal('45277'), Decimal('44178')),
#  ('Austria', Decimal('47427'), Decimal('45277')),
#  ('Austria', Decimal('51478'), Decimal('47427')),
#  ('Austria', Decimal('50138'), Decimal('51478')),
#  ('Belgium', Decimal('36796'), Decimal('36796')),
#  ('Belgium', Decimal('38673'), Decimal('36796')),
#  ('Belgium', Decimal('44263'), Decimal('38673')),
#  ('Belgium', Decimal('48107'), Decimal('44263')),
# ...

# %%
session.query(Cpi.country_name,Cpi.cpi_year,Cpi.cpi).all()
# Out:
# [('Austria', 2006, 1.4),
#  ('Austria', 2007, 2.2),
#  ('Austria', 2008, 3.2),
#  ('Austria', 2009, 0.5),
#  ('Austria', 2010, 1.8),
#  ('Austria', 2011, 3.3),
#  ('Austria', 2012, 2.5),
#  ('Austria', 2013, 2.0),
#  ('Austria', 2014, 1.6),
#  ('Austria', 2015, 0.9),
#  ('Austria', 2016, 0.9),
#  ('Austria', 2017, 2.1),
#  ('Austria', 2018, 2.0),
#  ('Austria', 2019, 1.5),
#  ('Belgium', 2006, 1.8),
#  ('Belgium', 2007, 1.8),
#  ('Belgium', 2008, 4.5),
#  ('Belgium', 2009, -0.1),
#  ('Belgium', 2010, 2.2),
#  ('Belgium', 2011, 3.5),
#  ('Belgium', 2012, 2.8),
#  ('Belgium', 2013, 1.1),
#  ('Belgium', 2014, 0.3),
#  ('Belgium', 2015, 0.6),
#  ('Belgium', 2016, 2.0),
#  ('Belgium', 2017, 2.1),
#  ('Belgium', 2018, 2.1),
#  ('Belgium', 2019, 1.4),
#  ('Bulgaria', 2006, 7.3),
#  ('Bulgaria', 2007, 8.4),
#  ('Bulgaria', 2008, 12.3),
#  ('Bulgaria', 2009, 2.8),
#  ('Bulgaria', 2010, 2.4),
#  ('Bulgaria', 2011, 4.2),
#  ('Bulgaria', 2012, 3.0),
#  ('Bulgaria', 2013, 0.9),
# ...

# %%
>>> from sqlalchemy import Table, MetaData
>>> from sqlalchemy.sql import text
>>> from sqlalchemy_views import CreateView, DropView

# %%
from sqlalchemy_views import sqlalchemy_views

# %%
pip install sqlalchemy_views

# %%
new_emp_df =pd.read_csv('static/beeswarm/unemp_EU4.csv')

# %%
new_emp_df.head(2)
# Out:
#   CountryName CountryCode    color  gdp_2016  gdp_2017  gdp_2018  gdp_2019  \
# 0     Austria         AUT  #a80f13     45277     47427     51478     50138
# 1     Belgium         BEL  #FFFF66     41984     44193     47583     46421
#
#    unemp_2016  unemp_2017  unemp_2018  unemp_2019
# 0        6.01        5.50        4.85        4.49
# 1        7.83        7.09        5.95        5.36

# %%
results = session.query(Countries.country_name,Countries.country_code,Gdp.gdp_year,Gdp.country_code,Countries.color,Unemployment.unemployment_pct,Unemployment.ump_year,Gdp.gdp_usd)\
                                    .filter(Unemployment.country_code == Countries.country_code)\
                                    .filter(Unemployment.country_code == Gdp.country_code,Unemployment.ump_year == Gdp.gdp_year)

# %%
for i,row in new_emp_df.iterrows():
    engine.execute(f"""UPDATE countries
SET color = '{row.color}'
   
WHERE country_code = '{row.CountryCode}';""")

# %%
columns = [result['name'] for result in results.column_descriptions]

# %%
row2dict = lambda r: {c:val for c,val in zip(columns,r)}

# %%
df_df = pd.DataFrame([row2dict(rez) for rez in results])

# %%
unemployment_df = df_df.pivot(index=['country_name','country_code','color'],columns= 'ump_year', values= 'unemployment_pct').rename(columns={col:f"unemployment_{col}" for col in df_df.ump_year.unique()})

# %%
gdp_df = df_df.pivot(index=['country_name','country_code','color'],columns= 'ump_year', values= 'gdp_usd').rename(columns={col:f"gdp_{col}" for col in df_df.ump_year.unique()}).applymap(float)

# %%
combined_df = gdp_df.join(unemployment_df).reset_index().rename(columns={"country_name": "CountryName", "country_code": "CountryCode"})

# %%
combined_df.to_dict(orient="records")
# Out:
# [{'CountryName': 'Austria',
#   'CountryCode': 'AUT',
#   'color': '#a80f13',
#   'gdp_2005': 38403.0,
#   'gdp_2006': 38403.0,
#   'gdp_2007': 40635.0,
#   'gdp_2008': 46856.0,
#   'gdp_2009': 51709.0,
#   'gdp_2010': 47963.0,
#   'gdp_2011': 46858.0,
#   'gdp_2012': 51375.0,
#   'gdp_2013': 48568.0,
#   'gdp_2014': 50717.0,
#   'gdp_2015': 51717.0,
#   'gdp_2016': 44178.0,
#   'gdp_2017': 45277.0,
#   'gdp_2018': 47427.0,
#   'gdp_2019': 51478.0,
#   'unemployment_2005': 5.63,
#   'unemployment_2006': 5.24,
#   'unemployment_2007': 4.86,
#   'unemployment_2008': 4.13,
#   'unemployment_2009': 5.3,
#   'unemployment_2010': 4.82,
#   'unemployment_2011': 4.56,
#   'unemployment_2012': 4.87,
#   'unemployment_2013': 5.34,
#   'unemployment_2014': 5.62,
#   'unemployment_2015': 5.72,
#   'unemployment_2016': 6.01,
#   'unemployment_2017': 5.5,
#   'unemployment_2018': 4.85,
#   'unemployment_2019': 4.49},
#  {'CountryName': 'Belgium',
#   'CountryCode': 'BEL',
#   'color': '#FFFF66',
# ...

# %%
countries_df = df_df[["country_code","country_name","color"]].drop_duplicates()

# %%
countries_df.set_index("country_code").to_dict(orient="index")
# Out:
# {'AUT': {'country_name': 'Austria', 'color': '#a80f13'},
#  'BEL': {'country_name': 'Belgium', 'color': '#FFFF66'},
#  'BGR': {'country_name': 'Bulgaria', 'color': '#00966E'},
#  'HRV': {'country_name': 'Croatia', 'color': '#dbc6a9'},
#  'CYP': {'country_name': 'Cyprus', 'color': '#D57800'},
#  'CZE': {'country_name': 'Czech Republic', 'color': '#11457E'},
#  'DNK': {'country_name': 'Denmark', 'color': '#8dbcf4'},
#  'EST': {'country_name': 'Estonia', 'color': '#999999'},
#  'FIN': {'country_name': 'Finland', 'color': '#33CCFF'},
#  'FRA': {'country_name': 'France', 'color': '#789263'},
#  'DEU': {'country_name': 'Germany', 'color': '#FFCD00'},
#  'GRC': {'country_name': 'Greece', 'color': '#0000ff'},
#  'HUN': {'country_name': 'Hungary', 'color': '#6c1245'},
#  'IRL': {'country_name': 'Ireland', 'color': '#a8e549'},
#  'ITA': {'country_name': 'Italy', 'color': '#006600'},
#  'LVA': {'country_name': 'Latvia', 'color': '#aa6f73'},
# ...

# %%
engine = create_engine("postgresql://postgres:postgres@localhost:5432/economy_db")

# %%
enginelite = create_engine("sqlite:///data/economy_db.sqlite")

# %%
result2 =session.query(Inflation.country_name,Inflation.country_code,Inflation.the_year,Inflation.inflation,Inflation.population,Inflation.color).all()

# %%
result2
# Out:
# [('Austria',
#   'AUT',
#   2005,
#   2.29914,
#   8227829,
#   '#a80f13                                                                                                                                                                                                                                                        '),
#  ('Belgium',
#   'BEL',
#   2005,
#   2.78143,
#   10478617,
#   '#FFFF66                                                                                                                                                                                                                                                        '),
#  ('Bulgaria',
#   'BGR',
#   2005,
#   5.03884,
#   7658972,
#   '#00966E                                                                                                                                                                                                                                                        '),
#  ('Croatia',
# ...

# %%
result3 =session.query(Gdp2.name,Gdp2.country_code,Gdp2.year,Gdp2.value,Gdp2.lastvalue).all()
result3
# Out:
# [('Austria', 'AUT', 2005, Decimal('38403'), Decimal('38403')),
#  ('Austria', 'AUT', 2006, Decimal('40635'), Decimal('38403')),
#  ('Austria', 'AUT', 2007, Decimal('46856'), Decimal('40635')),
#  ('Austria', 'AUT', 2008, Decimal('51709'), Decimal('46856')),
#  ('Austria', 'AUT', 2009, Decimal('47963'), Decimal('51709')),
#  ('Austria', 'AUT', 2010, Decimal('46858'), Decimal('47963')),
#  ('Austria', 'AUT', 2011, Decimal('51375'), Decimal('46858')),
#  ('Austria', 'AUT', 2012, Decimal('48568'), Decimal('51375')),
#  ('Austria', 'AUT', 2013, Decimal('50717'), Decimal('48568')),
#  ('Austria', 'AUT', 2014, Decimal('51717'), Decimal('50717')),
#  ('Austria', 'AUT', 2015, Decimal('44178'), Decimal('51717')),
#  ('Austria', 'AUT', 2016, Decimal('45277'), Decimal('44178')),
#  ('Austria', 'AUT', 2017, Decimal('47427'), Decimal('45277')),
#  ('Austria', 'AUT', 2018, Decimal('51478'), Decimal('47427')),
#  ('Austria', 'AUT', 2019, Decimal('50138'), Decimal('51478')),
# ...
